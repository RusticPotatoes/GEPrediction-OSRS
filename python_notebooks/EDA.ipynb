# %% [markdown]
# # ASOS Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/opt/app/data/workspace/GEPrediction-OSRS/data/Rune_Data.csv')
df.set_index('timestamp')
df.head()
# Out:
#        timestamp  Inquisitor's_armour_set  Arcane_spirit_shield  Arcane_sigil  \
# 0  1612569600000                519106987             158412167     157846710
# 1  1612656000000                530750252             157849673     157846710
# 2  1612742400000                537600325             159485087     157846710
# 3  1612828800000                531758548             159742245     157403161
# 4  1612915200000                526662014             159570496     157403161
#
#    Sanguinesti_staff_(uncharged)  Dragon_hunter_lance  Dragon_claws  \
# 0                       90576206             73522075      58397545
# 1                       90911736             73168441      58375225
# 2                       89566903             73085467      58412141
# 3                       89598655             73679496      58271575
# 4                       90447500             73624175      58044464
#
#    Craw's_bow_(u)  3rd_age_kiteshield  3rd_age_full_helmet  ...  \
# 0         7508944            25617804             15435283  ...
# 1         7544305            26420379             15307346  ...
# 2         7597889            26420379             15307346  ...
# 3         7590228            26418867             14996731  ...
# 4         7564829            26418867             14996731  ...
#
#    Gilded_armour_set_(lg)  Anglerfish  Manta_ray  Shark  Magic_logs  \
# 0                12516102        1050       1218    685         998
# 1                12516102        1052       1199    687        1001
# 2                12464455        1064       1211    686         995
# 3                12428341        1069       1179    693         999
# 4                12428341        1075       1157    687        1001
#
#    Smoke_battlestaff  Anguish_ornament_kit  Tormented_ornament_kit  \
# 0            1620324               7974044                 5176105
# 1            1629109               8106546                 5138850
# 2            1626838               8210233                 5234627
# 3            1623892               8147963                 5372897
# 4            1638033               8159175                 5379475
#
#    Occult_ornament_kit  Torture_ornament_kit
# 0              4238405               6214639
# 1              4319440               6145574
# 2              4448033               6121966
# 3              4540167               6074573
# 4              4571403               6111067
#
# [5 rows x 22 columns]

# %%
print(df.describe())
print(df.shape)
# Out:
#           timestamp  Inquisitor's_armour_set  Arcane_spirit_shield  \
# count  1.800000e+02             1.800000e+02          1.800000e+02
# mean   1.620302e+12             5.205521e+08          1.284547e+08
# std    4.501929e+09             5.789043e+07          1.923013e+07
# min    1.612570e+12             4.124960e+08          9.219965e+07
# 25%    1.616436e+12             4.727000e+08          1.116562e+08
# 50%    1.620302e+12             5.165350e+08          1.259482e+08
# 75%    1.624169e+12             5.727343e+08          1.411043e+08
# max    1.628035e+12             6.582540e+08          1.652915e+08
#
#        Arcane_sigil  Sanguinesti_staff_(uncharged)  Dragon_hunter_lance  \
# count  1.800000e+02                   1.800000e+02         1.800000e+02
# mean   1.301427e+08                   6.798888e+07         6.085797e+07
# std    1.866972e+07                   1.015954e+07         8.176513e+06
# min    1.025409e+08                   4.693003e+07         4.254391e+07
# 25%    1.167232e+08                   5.935963e+07         5.384714e+07
# 50%    1.296551e+08                   6.841553e+07         5.994031e+07
# 75%    1.405621e+08                   7.206956e+07         6.760487e+07
# max    1.623693e+08                   9.118261e+07         7.465465e+07
#
#        Dragon_claws  Craw's_bow_(u)  3rd_age_kiteshield  3rd_age_full_helmet  \
# count  1.800000e+02    1.800000e+02        1.800000e+02         1.800000e+02
# mean   5.519972e+07    1.157773e+07        3.508585e+07         2.265303e+07
# std    2.952960e+06    3.783378e+06        7.567654e+06         4.634043e+06
# min    4.987699e+07    7.508944e+06        2.521280e+07         1.435103e+07
# 25%    5.279075e+07    8.946697e+06        2.787220e+07         1.959343e+07
# 50%    5.490788e+07    9.697867e+06        3.463548e+07         2.209546e+07
# 75%    5.780648e+07    1.329348e+07        3.962559e+07         2.565523e+07
# max    6.210774e+07    1.987370e+07        5.150660e+07         3.223556e+07
#
#        ...  Gilded_armour_set_(lg)   Anglerfish   Manta_ray        Shark  \
# count  ...            1.800000e+02   180.000000   180.00000   180.000000
# mean   ...            1.336901e+07  1502.400000  1285.45000   872.405556
# std    ...            8.431447e+05   312.642988   170.35101   111.638217
# min    ...            1.195841e+07  1049.000000  1046.00000   655.000000
# 25%    ...            1.252556e+07  1192.750000  1141.00000   791.750000
# 50%    ...            1.320812e+07  1522.500000  1213.00000   903.000000
# 75%    ...            1.428360e+07  1806.500000  1441.75000   960.250000
# max    ...            1.470365e+07  2019.000000  1679.00000  1053.000000
#
#         Magic_logs  Smoke_battlestaff  Anguish_ornament_kit  \
# count   180.000000       1.800000e+02          1.800000e+02
# mean    996.672222       1.306618e+06          7.540249e+06
# std      34.405702       1.942367e+05          7.130602e+05
# min     906.000000       9.530160e+05          6.053350e+06
# 25%     991.750000       1.150721e+06          7.075210e+06
# 50%    1006.500000       1.264876e+06          7.589599e+06
# 75%    1018.000000       1.438199e+06          8.166244e+06
# max    1046.000000       1.692036e+06          8.734971e+06
#
#        Tormented_ornament_kit  Occult_ornament_kit  Torture_ornament_kit
# count            1.800000e+02         1.800000e+02          1.800000e+02
# mean             4.499039e+06         4.339055e+06          5.241557e+06
# std              6.268021e+05         4.389263e+05          6.183544e+05
# min              2.911323e+06         3.087172e+06          3.804615e+06
# 25%              4.007114e+06         4.079806e+06          4.953007e+06
# 50%              4.625332e+06         4.390442e+06          5.290768e+06
# 75%              5.091935e+06         4.571589e+06          5.559877e+06
# max              5.379475e+06         5.345878e+06          6.472366e+06
#
# [8 rows x 22 columns]
# (180, 22)

# %% [markdown]
# ## Distribution Plots & Heatmap

# %%
df.hist(bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'timestamp'}>,
#         <AxesSubplot:title={'center':"Inquisitor's_armour_set"}>,
#         <AxesSubplot:title={'center':'Arcane_spirit_shield'}>,
#         <AxesSubplot:title={'center':'Arcane_sigil'}>,
#         <AxesSubplot:title={'center':'Sanguinesti_staff_(uncharged)'}>],
#        [<AxesSubplot:title={'center':'Dragon_hunter_lance'}>,
#         <AxesSubplot:title={'center':'Dragon_claws'}>,
#         <AxesSubplot:title={'center':"Craw's_bow_(u)"}>,
#         <AxesSubplot:title={'center':'3rd_age_kiteshield'}>,
#         <AxesSubplot:title={'center':'3rd_age_full_helmet'}>],
#        [<AxesSubplot:title={'center':'3rd_age_robe'}>,
#         <AxesSubplot:title={'center':'Gilded_scimitar'}>,
#         <AxesSubplot:title={'center':'Gilded_armour_set_(lg)'}>,
#         <AxesSubplot:title={'center':'Anglerfish'}>,
#         <AxesSubplot:title={'center':'Manta_ray'}>],
#        [<AxesSubplot:title={'center':'Shark'}>,
#         <AxesSubplot:title={'center':'Magic_logs'}>,
#         <AxesSubplot:title={'center':'Smoke_battlestaff'}>,
#         <AxesSubplot:title={'center':'Anguish_ornament_kit'}>,
#         <AxesSubplot:title={'center':'Tormented_ornament_kit'}>],
#        [<AxesSubplot:title={'center':'Occult_ornament_kit'}>,
#         <AxesSubplot:title={'center':'Torture_ornament_kit'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
sns.boxplot(x=df['Arcane_spirit_shield'])
# Out:
# <AxesSubplot:xlabel='Arcane_spirit_shield'>

# %%
plt.figure(figsize=(20,10))
c= df.corr()
sns.heatmap(c,annot=True)
c
# Out:
#                                timestamp  Inquisitor's_armour_set  \
# timestamp                       1.000000                 0.728926
# Inquisitor's_armour_set         0.728926                 1.000000
# Arcane_spirit_shield           -0.961486                -0.663467
# Arcane_sigil                   -0.971036                -0.737850
# Sanguinesti_staff_(uncharged)  -0.891241                -0.448365
# Dragon_hunter_lance            -0.962766                -0.631477
# Dragon_claws                    0.222180                 0.318878
# Craw's_bow_(u)                  0.906128                 0.645204
# 3rd_age_kiteshield              0.697948                 0.726065
# 3rd_age_full_helmet             0.706801                 0.578255
# 3rd_age_robe                    0.873105                 0.658326
# Gilded_scimitar                 0.352727                 0.295209
# Gilded_armour_set_(lg)          0.604114                 0.624209
# Anglerfish                      0.976086                 0.751977
# Manta_ray                       0.856093                 0.713577
# Shark                           0.832032                 0.522653
# Magic_logs                     -0.646657                -0.422955
# Smoke_battlestaff              -0.858117                -0.664766
# Anguish_ornament_kit           -0.834965                -0.614622
# Tormented_ornament_kit         -0.830901                -0.470190
# Occult_ornament_kit            -0.211991                 0.149204
# Torture_ornament_kit           -0.688567                -0.365414
#
#                                Arcane_spirit_shield  Arcane_sigil  \
# timestamp                                 -0.961486     -0.971036
# Inquisitor's_armour_set                   -0.663467     -0.737850
# Arcane_spirit_shield                       1.000000      0.971304
# Arcane_sigil                               0.971304      1.000000
# Sanguinesti_staff_(uncharged)              0.934824      0.897388
# Dragon_hunter_lance                        0.974399      0.953254
# Dragon_claws                              -0.055948     -0.091367
# Craw's_bow_(u)                            -0.843153     -0.858829
# 3rd_age_kiteshield                        -0.684839     -0.688183
# 3rd_age_full_helmet                       -0.712598     -0.695547
# 3rd_age_robe                              -0.844384     -0.853938
# Gilded_scimitar                           -0.327952     -0.369109
# Gilded_armour_set_(lg)                    -0.610845     -0.628378
# Anglerfish                                -0.937708     -0.960051
# Manta_ray                                 -0.769930     -0.786290
# Shark                                     -0.804739     -0.843016
# Magic_logs                                 0.583028      0.590948
# Smoke_battlestaff                          0.823315      0.833554
# Anguish_ornament_kit                       0.817826      0.802846
# Tormented_ornament_kit                     0.867021      0.824396
# Occult_ornament_kit                        0.268772      0.207448
# Torture_ornament_kit                       0.725016      0.664002
#
#                                Sanguinesti_staff_(uncharged)  \
# timestamp                                          -0.891241
# Inquisitor's_armour_set                            -0.448365
# Arcane_spirit_shield                                0.934824
# Arcane_sigil                                        0.897388
# Sanguinesti_staff_(uncharged)                       1.000000
# Dragon_hunter_lance                                 0.940915
# Dragon_claws                                        0.106305
# Craw's_bow_(u)                                     -0.757236
# 3rd_age_kiteshield                                 -0.567608
# 3rd_age_full_helmet                                -0.675204
# 3rd_age_robe                                       -0.769780
# Gilded_scimitar                                    -0.356598
# Gilded_armour_set_(lg)                             -0.523186
# Anglerfish                                         -0.852985
# Manta_ray                                          -0.675406
# Shark                                              -0.847744
# Magic_logs                                          0.517592
# Smoke_battlestaff                                   0.746917
# Anguish_ornament_kit                                0.701266
# Tormented_ornament_kit                              0.826816
# Occult_ornament_kit                                 0.346134
# Torture_ornament_kit                                0.648600
#
#                                Dragon_hunter_lance  Dragon_claws  \
# timestamp                                -0.962766      0.222180
# Inquisitor's_armour_set                  -0.631477      0.318878
# Arcane_spirit_shield                      0.974399     -0.055948
# Arcane_sigil                              0.953254     -0.091367
# Sanguinesti_staff_(uncharged)             0.940915      0.106305
# Dragon_hunter_lance                       1.000000     -0.058626
# Dragon_claws                             -0.058626      1.000000
# Craw's_bow_(u)                           -0.837561      0.465696
# 3rd_age_kiteshield                       -0.672393      0.052174
# 3rd_age_full_helmet                      -0.708051     -0.040840
# 3rd_age_robe                             -0.868054      0.248723
# Gilded_scimitar                          -0.353194     -0.372569
# Gilded_armour_set_(lg)                   -0.614054     -0.229335
# Anglerfish                               -0.939048      0.215222
# Manta_ray                                -0.783647      0.466855
# Shark                                    -0.827241     -0.039764
# Magic_logs                                0.602387     -0.461901
# Smoke_battlestaff                         0.815467     -0.040659
# Anguish_ornament_kit                      0.832455     -0.204791
# Tormented_ornament_kit                    0.880929      0.000177
# Occult_ornament_kit                       0.308405      0.165446
# Torture_ornament_kit                      0.693440     -0.207378
#
#                                Craw's_bow_(u)  3rd_age_kiteshield  \
# timestamp                            0.906128            0.697948
# Inquisitor's_armour_set              0.645204            0.726065
# Arcane_spirit_shield                -0.843153           -0.684839
# Arcane_sigil                        -0.858829           -0.688183
# Sanguinesti_staff_(uncharged)       -0.757236           -0.567608
# Dragon_hunter_lance                 -0.837561           -0.672393
# Dragon_claws                         0.465696            0.052174
# Craw's_bow_(u)                       1.000000            0.418092
# 3rd_age_kiteshield                   0.418092            1.000000
# 3rd_age_full_helmet                  0.420734            0.936198
# 3rd_age_robe                         0.775483            0.707611
# Gilded_scimitar                      0.081226            0.403548
# Gilded_armour_set_(lg)               0.253002            0.866302
# Anglerfish                           0.863807            0.733800
# Manta_ray                            0.876369            0.585594
# Shark                                0.702560            0.518985
# Magic_logs                          -0.847420           -0.084948
# Smoke_battlestaff                   -0.640577           -0.807203
# Anguish_ornament_kit                -0.838688           -0.416258
# Tormented_ornament_kit              -0.757221           -0.470599
# Occult_ornament_kit                 -0.314291            0.337218
# Torture_ornament_kit                -0.781498           -0.209988
#
#                                3rd_age_full_helmet  ...  \
# timestamp                                 0.706801  ...
# Inquisitor's_armour_set                   0.578255  ...
# Arcane_spirit_shield                     -0.712598  ...
# Arcane_sigil                             -0.695547  ...
# Sanguinesti_staff_(uncharged)            -0.675204  ...
# Dragon_hunter_lance                      -0.708051  ...
# Dragon_claws                             -0.040840  ...
# Craw's_bow_(u)                            0.420734  ...
# 3rd_age_kiteshield                        0.936198  ...
# 3rd_age_full_helmet                       1.000000  ...
# 3rd_age_robe                              0.714604  ...
# Gilded_scimitar                           0.406857  ...
# Gilded_armour_set_(lg)                    0.816044  ...
# Anglerfish                                0.741968  ...
# Manta_ray                                 0.565414  ...
# Shark                                     0.604924  ...
# Magic_logs                               -0.071482  ...
# Smoke_battlestaff                        -0.784655  ...
# Anguish_ornament_kit                     -0.394272  ...
# Tormented_ornament_kit                   -0.509051  ...
# Occult_ornament_kit                       0.225527  ...
# Torture_ornament_kit                     -0.219728  ...
#
#                                Gilded_armour_set_(lg)  Anglerfish  Manta_ray  \
# timestamp                                    0.604114    0.976086   0.856093
# Inquisitor's_armour_set                      0.624209    0.751977   0.713577
# Arcane_spirit_shield                        -0.610845   -0.937708  -0.769930
# Arcane_sigil                                -0.628378   -0.960051  -0.786290
# Sanguinesti_staff_(uncharged)               -0.523186   -0.852985  -0.675406
# Dragon_hunter_lance                         -0.614054   -0.939048  -0.783647
# Dragon_claws                                -0.229335    0.215222   0.466855
# Craw's_bow_(u)                               0.253002    0.863807   0.876369
# 3rd_age_kiteshield                           0.866302    0.733800   0.585594
# 3rd_age_full_helmet                          0.816044    0.741968   0.565414
# 3rd_age_robe                                 0.571988    0.916264   0.787968
# Gilded_scimitar                              0.701741    0.347884   0.032169
# Gilded_armour_set_(lg)                       1.000000    0.651888   0.342817
# Anglerfish                                   0.651888    1.000000   0.823035
# Manta_ray                                    0.342817    0.823035   1.000000
# Shark                                        0.539450    0.825206   0.585578
# Magic_logs                                   0.101762   -0.581765  -0.720013
# Smoke_battlestaff                           -0.773956   -0.820548  -0.670096
# Anguish_ornament_kit                        -0.426059   -0.815623  -0.709504
# Tormented_ornament_kit                      -0.497298   -0.826506  -0.591108
# Occult_ornament_kit                          0.140279   -0.199334  -0.050665
# Torture_ornament_kit                        -0.133636   -0.647595  -0.606418
#
#                                   Shark  Magic_logs  Smoke_battlestaff  \
# timestamp                      0.832032   -0.646657          -0.858117
# Inquisitor's_armour_set        0.522653   -0.422955          -0.664766
# Arcane_spirit_shield          -0.804739    0.583028           0.823315
# Arcane_sigil                  -0.843016    0.590948           0.833554
# Sanguinesti_staff_(uncharged) -0.847744    0.517592           0.746917
# Dragon_hunter_lance           -0.827241    0.602387           0.815467
# Dragon_claws                  -0.039764   -0.461901          -0.040659
# Craw's_bow_(u)                 0.702560   -0.847420          -0.640577
# 3rd_age_kiteshield             0.518985   -0.084948          -0.807203
# 3rd_age_full_helmet            0.604924   -0.071482          -0.784655
# 3rd_age_robe                   0.676402   -0.507774          -0.652109
# Gilded_scimitar                0.568379    0.117040          -0.602807
# Gilded_armour_set_(lg)         0.539450    0.101762          -0.773956
# Anglerfish                     0.825206   -0.581765          -0.820548
# Manta_ray                      0.585578   -0.720013          -0.670096
# Shark                          1.000000   -0.494731          -0.736391
# Magic_logs                    -0.494731    1.000000           0.381823
# Smoke_battlestaff             -0.736391    0.381823           1.000000
# Anguish_ornament_kit          -0.623518    0.706414           0.640806
# Tormented_ornament_kit        -0.710595    0.580392           0.660759
# Occult_ornament_kit           -0.284033    0.423735          -0.045955
# Torture_ornament_kit          -0.412941    0.666581           0.423984
#
#                                Anguish_ornament_kit  Tormented_ornament_kit  \
# timestamp                                 -0.834965               -0.830901
# Inquisitor's_armour_set                   -0.614622               -0.470190
# Arcane_spirit_shield                       0.817826                0.867021
# Arcane_sigil                               0.802846                0.824396
# Sanguinesti_staff_(uncharged)              0.701266                0.826816
# Dragon_hunter_lance                        0.832455                0.880929
# Dragon_claws                              -0.204791                0.000177
# Craw's_bow_(u)                            -0.838688               -0.757221
# 3rd_age_kiteshield                        -0.416258               -0.470599
# 3rd_age_full_helmet                       -0.394272               -0.509051
# 3rd_age_robe                              -0.709937               -0.738837
# Gilded_scimitar                           -0.273985               -0.310633
# Gilded_armour_set_(lg)                    -0.426059               -0.497298
# Anglerfish                                -0.815623               -0.826506
# Manta_ray                                 -0.709504               -0.591108
# Shark                                     -0.623518               -0.710595
# Magic_logs                                 0.706414                0.580392
# Smoke_battlestaff                          0.640806                0.660759
# Anguish_ornament_kit                       1.000000                0.898178
# Tormented_ornament_kit                     0.898178                1.000000
# Occult_ornament_kit                        0.543858                0.579452
# Torture_ornament_kit                       0.844677                0.808455
#
#                                Occult_ornament_kit  Torture_ornament_kit
# timestamp                                -0.211991             -0.688567
# Inquisitor's_armour_set                   0.149204             -0.365414
# Arcane_spirit_shield                      0.268772              0.725016
# Arcane_sigil                              0.207448              0.664002
# Sanguinesti_staff_(uncharged)             0.346134              0.648600
# Dragon_hunter_lance                       0.308405              0.693440
# Dragon_claws                              0.165446             -0.207378
# Craw's_bow_(u)                           -0.314291             -0.781498
# 3rd_age_kiteshield                        0.337218             -0.209988
# 3rd_age_full_helmet                       0.225527             -0.219728
# 3rd_age_robe                             -0.131144             -0.565816
# Gilded_scimitar                          -0.067944              0.038988
# Gilded_armour_set_(lg)                    0.140279             -0.133636
# Anglerfish                               -0.199334             -0.647595
# Manta_ray                                -0.050665             -0.606418
# Shark                                    -0.284033             -0.412941
# Magic_logs                                0.423735              0.666581
# Smoke_battlestaff                        -0.045955              0.423984
# Anguish_ornament_kit                      0.543858              0.844677
# Tormented_ornament_kit                    0.579452              0.808455
# Occult_ornament_kit                       1.000000              0.567419
# Torture_ornament_kit                      0.567419              1.000000
#
# [22 rows x 22 columns]
